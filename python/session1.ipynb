# %%
## Lambad function
greating = lambda name: f"Hello, {name}!"
print(greating("Alice"))
# Out:
# Hello, Alice!

# %%
## Map function
numbers = [1, 2, 3, 4, 5]
squared_numbers = list(map(lambda x: x**2, numbers))
print(squared_numbers)
# Out:
# [1, 4, 9, 16, 25]

# %%
## List comprehension
list_comprehension = [x**2 for x in numbers]
print(list_comprehension)
# Out:
# [1, 4, 9, 16, 25]

# %%
## filiter function
even_numbers = list(filter(lambda x: x % 2 == 0, numbers))
print(even_numbers)
# Out:
# [2, 4]

# %%
class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary

    def __repr__(self):
        return f"Employee(name={self.name}, salary={self.salary})"

# %%
employees = [
    Employee("Alice", 70000),
    Employee("Bob", 50000),
    Employee("Charlie", 60000)
]
print(employees)
sorted_employees = sorted(employees, key=lambda emp: emp.salary)
print(sorted_employees)
# Out:
# [Employee(name=Alice, salary=70000), Employee(name=Bob, salary=50000), Employee(name=Charlie, salary=60000)]
# [Employee(name=Bob, salary=50000), Employee(name=Charlie, salary=60000), Employee(name=Alice, salary=70000)]

# %%
import json
person = {"name": "Alice", "age": 30, "city": "New York"}
person_json = json.dumps(person)

# %%
print(person_json)
# Out:
# {"name": "Alice", "age": 30, "city": "New York"}

# %%
person_dict = json.loads(person_json)
print(person_dict)
# Out:
# {'name': 'Alice', 'age': 30, 'city': 'New York'}

# %%
## Open file and read and write
with open("test.txt", "w") as file:
    file.write("Welcome to the file!")

# %%
with open("test.txt", "r") as file:
    content = file.read()
    print(content)
# Out:
# Welcome to the file!

# %%
with open("test.txt", "a") as file:
    file.write("Additional content.")

with open("test.txt", "r") as file:
    content = file.read()
    print(content)
# Out:
# Welcome to the file!Additional content.
