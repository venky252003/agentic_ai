# %%
from utils import authenticate
import vertexai
import kfp as dsl
from kfp import compiler
from google.cloud import bigquery
credentials, PROJECT_ID = authenticate()
# Out:
# e:\python\ik_coding\agentic_ai\.venv\Lib\site-packages\kfp\dsl\_ops_group.py:65: SyntaxWarning: invalid escape sequence '\d'
#   name_pattern = '^' + (group_type + '-' + name + '-').replace('_', '-') + '[\d]+$'
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 3
#       1 from utils import authenticate
#       2 import vertexai
# ----> 3 import kfp as dsl
#       4 from kfp import compiler
#       5 from google.cloud import bigquery
#
# File e:\python\ik_coding\agentic_ai\.venv\Lib\site-packages\kfp\__init__.py:24
#      22 from . import containers
#      23 from . import dsl
# ---> 24 from ._client import Client
#      25 from ._config import *
#      26 from ._runners import *
#
# File e:\python\ik_coding\agentic_ai\.venv\Lib\site-packages\kfp\_client.py:34
#      31 from kfp.compiler import compiler
#      32 from kfp.compiler._k8s_helper import sanitize_k8s_name
# ---> 34 from kfp._auth import get_auth_token, get_gcp_access_token
#      36 # TTL of the access token associated with the client. This is needed because
#      37 # `gcloud auth print-access-token` generates a token with TTL=1 hour, after
#      38 # which the authentication expires. This TTL is needed for kfp.Client()
#      39 # initialized with host=<inverse proxy endpoint>.
#      40 # Set to 55 mins to provide some safe margin.
#      41 _GCP_ACCESS_TOKEN_TIMEOUT = datetime.timedelta(minutes=55)
#
# File e:\python\ik_coding\agentic_ai\.venv\Lib\site-packages\kfp\_auth.py:24
#      22 import google.oauth2.credentials
#      23 import google.oauth2.service_account
# ---> 24 import requests_toolbelt.adapters.appengine
#      25 from webbrowser import open_new_tab
#      26 import requests
#
# File e:\python\ik_coding\agentic_ai\.venv\Lib\site-packages\requests_toolbelt\adapters\appengine.py:42
#      39 from requests import sessions
#      41 from .. import exceptions as exc
# ---> 42 from .._compat import gaecontrib
#      43 from .._compat import timeout
#      46 class AppEngineMROHack(adapters.HTTPAdapter):
#
# ImportError: cannot import name 'gaecontrib' from 'requests_toolbelt._compat' (e:\python\ik_coding\agentic_ai\.venv\Lib\site-packages\requests_toolbelt\_compat.py)

# %%
from kfp import dsl
from kfp import compiler

# Ignore FutureWarnings in kfp
import warnings
warnings.filterwarnings("ignore", 
                        category=FutureWarning, 
                        module='kfp.*')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from kfp import dsl
#       2 from kfp import compiler
#       4 # Ignore FutureWarnings in kfp
#
# File e:\python\ik_coding\agentic_ai\.venv\Lib\site-packages\kfp\__init__.py:24
#      22 from . import containers
#      23 from . import dsl
# ---> 24 from ._client import Client
#      25 from ._config import *
#      26 from ._runners import *
#
# File e:\python\ik_coding\agentic_ai\.venv\Lib\site-packages\kfp\_client.py:34
#      31 from kfp.compiler import compiler
#      32 from kfp.compiler._k8s_helper import sanitize_k8s_name
# ---> 34 from kfp._auth import get_auth_token, get_gcp_access_token
#      36 # TTL of the access token associated with the client. This is needed because
#      37 # `gcloud auth print-access-token` generates a token with TTL=1 hour, after
#      38 # which the authentication expires. This TTL is needed for kfp.Client()
#      39 # initialized with host=<inverse proxy endpoint>.
#      40 # Set to 55 mins to provide some safe margin.
#      41 _GCP_ACCESS_TOKEN_TIMEOUT = datetime.timedelta(minutes=55)
#
# File e:\python\ik_coding\agentic_ai\.venv\Lib\site-packages\kfp\_auth.py:24
#      22 import google.oauth2.credentials
#      23 import google.oauth2.service_account
# ---> 24 import requests_toolbelt.adapters.appengine
#      25 from webbrowser import open_new_tab
#      26 import requests
#
# File e:\python\ik_coding\agentic_ai\.venv\Lib\site-packages\requests_toolbelt\adapters\appengine.py:42
#      39 from requests import sessions
#      41 from .. import exceptions as exc
# ---> 42 from .._compat import gaecontrib
#      43 from .._compat import timeout
#      46 class AppEngineMROHack(adapters.HTTPAdapter):
#
# ImportError: cannot import name 'gaecontrib' from 'requests_toolbelt._compat' (e:\python\ik_coding\agentic_ai\.venv\Lib\site-packages\requests_toolbelt\_compat.py)

# %%
REGION = "us-central1"
vertexai.init(project = PROJECT_ID,
              location = REGION,
              credentials = credentials)
